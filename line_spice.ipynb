# %%
import os
import json
from dotenv import load_dotenv
from langchain.chat_models import ChatOpenAI
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# .env 파일 로드
load_dotenv()

# 환경 변수에서 API 키 읽기
openai_api_key = os.getenv("OPENAI_API_KEY")

# LangChain ChatOpenAI 모델 설정
chat_model = ChatOpenAI(api_key=openai_api_key, model="gpt-3.5-turbo")

# 향료 데이터 로드
file_path = "spice.json"
with open(file_path, "r", encoding="utf-8") as file:
    fragrances = json.load(file)

# 계열 정보
categories = [
    "Spicy", "Chypre", "Fruity", "Citrus", "Green", "Aldehyde", "Aquatic",
    "Fougere", "Gourmand", "Woody", "Oriental", "Floral", "Musk",
    "Powdery", "Tobacco Leather", "Amber"
]

# 향료 설명을 분류하는 프롬프트 템플릿
prompt_template = """Classify the following fragrance descriptions into one of these categories: {categories}.

Descriptions:
{descriptions}

Ensure the classification strictly follows the given categories. Return the results in JSON format, with each fragrance name and its category.
"""

# 프롬프트 템플릿 설정
prompt = PromptTemplate(input_variables=["categories", "descriptions"], template=prompt_template)

# LLMChain 생성
llm_chain = LLMChain(llm=chat_model, prompt=prompt)

# 향료 설명을 분류하는 함수
def classify_fragrances_batch(fragrances, categories):
    descriptions = [f"- {item['name']}: {item['content']}" for item in fragrances]
    
    # LLMChain 실행 (프롬프트에 categories와 descriptions 값을 전달)
    result = llm_chain.run(categories=', '.join(categories), descriptions='\n'.join(descriptions))
    
    # 결과 출력 (디버깅용)
    print("Result from model:", result)
    
    # 결과가 빈 값이 아닌지 확인
    if result.strip():
        try:
            return json.loads(result.strip())
        except json.JSONDecodeError as e:
            print(f"JSON decoding error: {e}")
            return None
    else:
        print("Result is empty.")
        return None

# 분류 실행
result = classify_fragrances_batch(fragrances, categories)

# 결과 출력 및 저장
if result:
    output_file_path = "classified_fragrances.json"
    with open(output_file_path, "w", encoding="utf-8") as output_file:
        json.dump(result, output_file, ensure_ascii=False, indent=4)

    print(f"분류 결과가 {output_file_path}에 저장되었습니다!")
else:
    print("분류 결과가 없거나 JSON 형식이 잘못되었습니다.")
# Out:
# Result from model: {
#   "Bergamot": "Citrus",
#   "Bitter Orange": "Citrus",
#   "Blood Orange": "Citrus",
#   "Buddha's hand": "Citrus",
#   "Chinotto": "Citrus",
#   "Citron": "Citrus",
#   "Clementine": "Citrus",
#   "Finger Lime": "Citrus",
#   "Grapefruit": "Citrus",
#   "Hassaku": "Citrus",
#   "Lemon": "Citrus",
#   "Lemon Balm": "Citrus",
#   "Lemon Tree": "Citrus",
#   "Lemon Verbena": "Citrus",
#   "Lemongrass": "Citrus",
#   "Limetta": "Citrus",
#   "Litsea Cubeba": "Citrus",
#   "Mandora": "Citrus",
#   "Methyl Pamplemousse": "Citrus",
#   "Neroli": "Citrus",
#   "Orange": "Citrus",
#   "Palestinian Sweet Lime": "Citrus",
#   "Rangpur": "Citrus",
#   "Sudachi citrus": "Citrus",
#   "Tangelo": "Citrus",
#   "Tangerine": "Citrus",
#   "Yuzu": "Citrus",
#   "Almond": "Gourmand",
#   "Artichoke": "Green",
#   "Banana": "Fruity",
#   "Barberry": "Fruity",
#   "Bearberry": "Fruity",
#   "Black Sapote": "Fruity",
#   "Blackberry": "Fruity",
#   "Breadnut": "Fruity",
#   "Carambola (Star Fruit)": "Fruity",
#   "Carrot": "Powdery",
#   "Cepes": "Musk",
#   "Cherry": "Fruity",
#   "Cocoa Shell": "Gourmand",
#   "Coconut": "Gourmand",
#   "Cucumber": "Green",
#   "Cupuaçu, Cupuassu, Copoasu": "Fruity",
#   "Currant Leaf and Bud": "Fruity",
#   "Cyperus Scariosus": "Woody",
#   "Daikon Radish": "Green",
#   "Dried Fruits": "Gourmand",
#   "Feijoa Fruit": "Fruity",
#   "Fig": "Fruity",
#   "Fig Leaf": "Green",
#   "Forest Fruits": "Fruity",
#   "Fuji Apple": "Fruity",
#   "Gariguette Strawberry": "Fruity",
#   "Guava": "Fruity",
#   "Hog Plum": "Fruity",
#   "Kiwi": "Fruity",
#   "Litchi": "Fruity",
#   "Malt": "Gourmand",
#   "Mamey": "Fruity",
#   "Mango": "Fruity",
#   "Mangosteen": "Fruity",
#   "Melon": "Fruity",
#   "Mirabelle": "Fruity",
#   "Miracle Berry": "Fruity",
#   "Mushroom": "Green",
#   "Nectarine": "Fruity",
#   "Okra Seeds": "Vegetal",
#   "Papaya": "Fruity",
#   "Passionfruit": "Fruity",
#   "Peach": "Fruity",
#   "Pear": "Fruity",
#   "Pecan": "Gourmand",
#   "Pineapple": "Fruity",
#   "Pistachio": "Gourmand",
#   "Pitahaya": "Fruity",
#   "Plum": "Fruity",
#   "Pomegranate": "Fruity",
#   "Pumpkin": "Gourmand",
#   "Red Apple": "Fruity",
#   "Red Currant": "Fruity",
#   "Rhubarb": "Fruity",
#   "Soybean": "Vegetal",
#   "Strawberry": "Fruity",
#   "Tayberry": "Fruity",
#   "Tomato": "Vegetal",
#   "Tropical Fruits": "Fruity",
#   "Tropicalone": "Fruity",
#   "Watermelon": "Fruity",
#   "White Currant": "Fruity",
#   "Wild Strawberry": "Fruity",
#   "Yellow Cherry": "Fruity",
#   "Aglaia": "Floral",
#   "Althaea": "Floral",
#   "Alyssum": "Floral",
#   "Amarillys": "Floral",
#   "Anemone": "Floral",
#   "Angel's Trumpet": "Floral",
#   "Apple Blossom": "Floral",
#   "Apricot Blossom": "Floral",
#   "Black Currant Blossom": "Floral",
#   "Blue Poppy": "Floral",
#   "Bluebell": "Floral",
#   "Camellia": "Floral",
#   "Chamomile": "Floral",
#   "Champaca": "Floral",
#   "Cherry Blossom": "Floral",
#   "Chocolate Flower": "Gourmand",
#   "Chrysanthemum": "Floral",
#   "Clematis": "Floral",
#   "Clover": "Floral",
#   "Costus": "Floral",
#   "Cyclamen": "Floral",
#   "Dandelion": "Floral",
#   "Deadnettle": "Floral",
#   "Elderflower": "Floral",
#   "English Marigold": "Floral",
#   "Flax": "Floral",
#   "Forget Me Not": "Floral",
#   "Freesia": "Floral",
#   "Grapeflower": "Floral",
#   "Hawthorn": "Floral",
#   "Heather": "Floral",
#   "Heliotrope": "Floral",
#   "Hellabore Flower": "Floral",
#   "Hoya Carnosa Wax Plant": "Floral",
#   "Hyacinth": "Floral",
#   "Hyssop": "Floral",
#   "Impatiens": "Floral",
#   "Iris": "Floral",
#   "Jarana Flower": "Floral",
#   "Kadam": "Floral",
#   "Kiwi blossom": "Floral",
#   "Laburnum": "Floral",
#   "Lavender": "Floral",
#   "Liatris": "Floral",
#   "Lilac": "Floral",
#   "Lydia Broom": "Floral",
#   "Magnolia": "Floral",
#   "Magnolia Brooklynensis": "Floral",
#   "Magnolia Leaf": "Floral",
#   "Malva": "Floral",
#   "Mango Blossom": "Floral",
#   "Mignonette": "Floral",
#   "Mimosa": "Floral",
#   "Mirabilis": "Floral",
#   "Monoi Oil": "Floral",
#   "Moss Flox": "Floral",
#   "Myrtle": "Floral",
#   "Narcissus": "Floral",
#   "Nasturtium": "Floral",
#   "Nerium Oleander": "Floral",
#   "Nigella": "Floral",
#   "Night Blooming Jasmine": "Floral",
#   "Orchid": "Floral",
#   "Orris Root": "Floral",
#   "Passion Flower": "Floral",
#   "Pear Blossom": "Floral",
#   "Peony": "Floral",
#   "Petalia": "Floral",
#   "Pineapple Blossom": "Floral",
#   "Pinwheel Flower": "Floral",
#   "Poinsettia": "Floral",
#   "Pomegranate Blossom": "Floral",
#   "Privet": "Floral",
#   "Rangoon Creeper": "Floral",
#   "Raspberry Blossom": "Floral",
#   "Rosa Alba": "Floral",
#   "Rose": "Floral",
#   "Rose Hip": "Floral",
#   "Rose Japanese (Hamanasu)": "Floral",
#   "Rose Mallow": "Floral",
#   "Rosyfolia": "Floral",
#   "Safflower": "Floral",
#   "Sand": "Green",
#   "Sandalwood Flower": "Floral",
#   "Siberian Rhododendron": "Floral",
#   "Snowdrops": "Floral",
#   "Sour Cherry Blossom": "Floral",
#   "Spanish Broom": "Floral",
#   "Strelitzia": "Floral",
#   "Sunflower": "Floral",
#   "Sweet Pea": "Floral",
#   "Taif Rose": "Floral",
#   "Tobacco Blossom": "Floral",
#   "Viburnum": "Floral",
#   "Water Hyacinth": "Floral",
#   "Water Lily": "Floral",
#   "Wildflowers": "Floral",
#   "Wisteria": "Floral",
#   "Arum Lily": "Floral",
#   "Black Locust": "Floral",
#   "Boronia": "Floral",
#   "Carissa": "Floral",
#   "Datura": "Floral",
#   "Frangipani": "Floral",
#   "Gardenia": "Floral",
#   "Grapefruit Blossom": "Floral",
#   "Honeysuckle": "Floral",
#   "Jasmine": "Floral",
#   "Lemon Blossom": "Floral",
#   "Lily": "Floral",
#   "Mandarin Orange Blossom": "Floral",
#   "Mock Orange": "Floral",
#   "Night Blooming Cereus": "Floral",
#   "Orange Blossom": "Floral",
#   "Syringa": "Floral",
#   "Tangerine Blossom": "Floral",
#   "Tiare Flower": "Floral",
#   "Aloe Vera": "Green",
#   "Angelica": "Green",
#   "Arnica": "Green",
#   "Avocado": "Green",
#   "Banana Leaf": "Green",
#   "Buchu or Agathosma": "Green",
#   "Bulrush": "Green",
#   "Calamus": "Green",
#   "Calycanthus": "Green",
#   "Cannabis": "Green",
#   "Celery": "Green",
#   "Celery Seeds": "Green",
#   "Coleus": "Green",
#   "Crithmum": "Green",
#   "Davana": "Green",
#   "Fern": "Green",
#   "Flouve": "Green",
#   "Grass": "Green",
#   "Green Notes": "Green",
#   "Hat Straw": "Green",
#   "Hedione": "Green",
#   "Hyssop": "Green",
#   "Indole": "Green",
#   "Jasmine Tea": "Green",
#   "Lava": "Green",
#   "Lorenox": "Green",
#   "Nootka": "Green",
#   "Olive Leaf": "Green",
#   "Palm Leaf": "Green",
#   "Paperbark": "Green",
#   "Papyrus": "Green",
#   "Pear Tree": "Green",
#   "Plum Tree": "Green",
#   "Sequoia": "Green",
#   "Slate": "Green",
#   "Spiranol": "Green",
#   "Tolu Balsam": "Green",
#   "Truffle": "Green",
#   "Vinyl Guaiacol": "Green",
#   "Agarwood (Oud)": "Woody",
#   "Akigalawood": "Woody",
#   "Amyris": "Woody",
#   "Birch": "Woody",
#   "Blackwood": "Woody",
#   "Brazilian Rosewood": "Woody",
#   "Buddha Wood": "Woody",
#   "Buxus": "Woody",
#   "Cabreuva": "Woody",
#   "Cedar": "Woody",
#   "Clearwood": "Woody",
#   "Cocobolo": "Woody",
#   "Cuban Cigar": "Woody",
#   "Fir": "Woody",
#   "Hinoki Wood": "Woody",
#   "Larch": "Woody",
#   "Lichen": "Woody",
#   "Mastic or Lentisque": "Woody",
#   "Myrrh": "Woody",
#   "Oak": "Woody",
#   "Olive Tree": "Woody",
#   "Palisander Rosewood": "Woody",
#   "Palo Santo": "Woody",
#   "Paperbark": "Woody",
#   "Papyrus": "Woody",
#   "Pine": "Woody",
#   "Rosewood": "Woody",
#   "Smoke": "Woody",
#   "Teak Wood": "Woody",
#   "Thuja": "Woody",
#   "Vetiver": "Woody",
#   "Amber": "Amber",
#   "Amber Xtreme": "Amber",
#   "Ambergris": "Amber",
#   "Benzoin": "Amber",
#   "Brown Scotch Tape": "Amber",
#   "Coca-Cola": "Gourmand",
#   "Coffee": "Gourmand",
#   "Cognac": "Gourmand",
#   "Cream Soda": "Gourmand",
#   "Génépi": "Gourmand",
#   "Gin": "Gourmand",
#   "Mocha": "Gourmand",
#   "Panna Cotta": "Gourmand",
#   "Pina Colada": "Gourmand",
#   "Rhum Agricole": "Gourmand",
#   "Soy Milk": "Gourmand",
#   "Tequila": "Gourmand",
#   "Vodka": "Gourmand",
#   "Whiskey": "Gourmand",
#   "White Wine": "Gourmand"
# }
# 분류 결과가 classified_fragrances.json에 저장되었습니다!
